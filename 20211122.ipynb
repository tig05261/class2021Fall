# %% [markdown]
# <a href="https://colab.research.google.com/github/tig05261/class2021Fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# parameter setting
amp = 1          # range [0.0, 1.0]
sr = 10000       # sampling rate, Hz
dur = 0.5        # in seconds
freq = 100.0     # sine frequency, Hz
phase = np.pi/2  # phase, radian

# %%
# generate samples
nSamp = sr * dur
samples = np.arange(1, nSamp+1)

# %%
# convert samples to time
t = samples/sr

# %%
# convert time to angle in radian
theta0 = t * 2*np.pi * freq

# %%
# shift angle by phase
theta = theta0 + phase

# %%
# generate signal by sin-phasor
s = amp * np.sin(theta)

# %%
# plot the entire signal
plt.plot(t, s, ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
# plot a certain of signals
sampleRng = np.arange(0,100)
plt.plot(t[sampleRng], s[sampleRng], ':')
plt.xlabel('time (s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
ipd.Audio(s, rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 440; phase = 0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp = 1; sr = 10000; phase = 0

F  =  349.23
Ab =  415.30
A  =  440.00
Bb =  466.16
C  =  523.25
Db =  554.37
Eb =  622.25

s_all = np.empty(0)

# %%
# 벤 -  열애중

notes = [Ab, Ab, Bb, C, 0, C, C, 0, Ab, Bb, C, C, C, \
         Bb, Db, 0, C, Bb, Ab, Bb, C, C, 0, C, Db, Eb, \
         Db, Db, C, C, A, Bb, C, C, Db, Db, 0, Bb, C, \
         Db, C, C, Bb, Bb, Ab, G, Eb, Eb, 0, F, C, C, \
         Bb, Bb, 0, Ab, Bb, C, Db, C, Bb, Ab, G, Ab]
durs = [0.5, 0.5, 0.5, 1.0, 0.25, 0.25, 0.5, 0.5, 0.25, 0.5, 0.5, 0.5, 0.5, \
        0.5, 0.75, 0.25, 0.5, 0.5, 0.5, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, \
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.5, 0.5, 0.5, 0.5, \
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 1.0, 0.5, 0.5, \
        0.5, 0.75, 0.75, 0.75, 0.5, 0.25, 0.5, \
        0.5, 0.5, 0.75, 0.75, 0.75, 0.75, 1.5]

# %%
len(durs)
# Out:
# 64

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
